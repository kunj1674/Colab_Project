# %% [markdown]
# <a href="https://colab.research.google.com/github/kunj1674/Colab_Project/blob/master/Data_Cleaning_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
#
# As a data scientist, you have to first explore the data and check its sanity.
# Further, you have to answer the following questions:
#
# 1.Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.
#
# 2.This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?
#
# 3.Find out the unique genres of movies in this dataset.
#
# 4.Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %% [markdown]
# Data Exploration

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/imdb_data.csv')

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['profit']=df['revenue']-df['budget']
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
df[df['profit']==df['profit'].max()][['title']]
# Out:
#           title
# 1761  Furious 7

# %%
df[df['profit']==df['profit'].max()][['cast']]
# Out:
#                                                    cast
# 1761  [{'cast_id': 17, 'character': 'Dominic Toretto...

# %%
df[df['profit']==df['profit'].max()][['crew']].values[0][0]
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0])
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
for i in eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0]):
  print(i['name'],'->',i['job'])
# Out:
# Vin Diesel -> Producer
# Neal H. Moritz -> Producer
# Chris Morgan -> Writer
# Gary Scott Thompson -> Characters
# James Wan -> Director
# Stephen F. Windon -> Director of Photography
# Tony Mecca -> Animation
# Marc Spicer -> Director of Photography
# Samantha Vincent -> Executive Producer
# F. Valentino Morales -> Associate Producer
# Michael Fottrell -> Producer
# Brandon Birtell -> Producer
# Leigh Folsom Boyd -> Editor
# Dylan Highsmith -> Editor
# Kirk M. Morri -> Editor
# Christian Wagner -> Editor
# Anne McCarthy -> Casting
# Kellie Roy -> Casting
# Jonathan Carlos -> Art Direction
# Alan Hook -> Art Direction
# Jay Pelissier -> Art Direction
# Kelly Richardson -> Art Department Coordinator
# Courtney Cocherell -> Art Department Coordinator
# Elena Albanese -> Assistant Art Director
# Alex McCarroll -> Assistant Art Director
# Bruce Di Valerio -> Construction Coordinator
# Bill Brzeski -> Production Design
# Danielle Berman -> Set Decoration
# ...

# %%
for i in eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0]):
  if i['job']=='Producer':
   print(i['name'])

print("Director Name-")
for i in eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0]):
  if i['job']=='Director':
   print(i['name'])
# Out:
# Vin Diesel
# Neal H. Moritz
# Michael Fottrell
# Brandon Birtell
# Director Name-
# James Wan

# %% [markdown]
# **1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.**

# %%
# Method one.
actor_list=[]
for i in eval(df[df['profit']==df['profit'].max()][['cast']].values[0][0]):
  actor_list.append(i['name'])

print(actor_list)
# Out:
# ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Michelle Rodriguez', 'Tyrese Gibson', 'Ludacris', 'Jordana Brewster', 'Djimon Hounsou', 'Tony Jaa', 'Ronda Rousey', 'Nathalie Emmanuel', 'Kurt Russell', 'Jason Statham', 'Sung Kang', 'Gal Gadot', 'Lucas Black', 'Elsa Pataky', 'Noel Gugliemi', 'John Brotherton', 'Luke Evans', 'Ali Fazal', 'Miller Kimsey', 'Charlie Kimsey', 'Eden Estrella', 'Gentry White', 'Iggy Azalea', 'Jon Lee Brody', 'Levy Tran', 'Anna Colwell', 'Viktor Hernandez', 'Steve Coulter', 'Robert Pralgo', 'Antwan Mills', 'J.J. Phillips', 'Jorge Ferragut', 'Sara Sohn', 'Benjamin Blankenship', 'D.J. Hapa', 'T-Pain', 'Brian Mahoney', 'Brittney Alger', 'Romeo Santos', 'Jocelin Donahue', 'Stephanie Langston', 'Jorge-Luis Pallo', 'Tego Calderón', 'Nathalie Kelley', 'Shad Moss', 'Don Omar', 'Klement Tinaj', 'Caleb Walker', 'Cody Walker']

# %%
# Method two
actor_list1=[]
for i in df[df['profit']==df['profit'].max()]['cast']:
  for j in eval(i):
    actor_list1.append(j['name'])


print(actor_list1)
# Out:
# ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Michelle Rodriguez', 'Tyrese Gibson', 'Ludacris', 'Jordana Brewster', 'Djimon Hounsou', 'Tony Jaa', 'Ronda Rousey', 'Nathalie Emmanuel', 'Kurt Russell', 'Jason Statham', 'Sung Kang', 'Gal Gadot', 'Lucas Black', 'Elsa Pataky', 'Noel Gugliemi', 'John Brotherton', 'Luke Evans', 'Ali Fazal', 'Miller Kimsey', 'Charlie Kimsey', 'Eden Estrella', 'Gentry White', 'Iggy Azalea', 'Jon Lee Brody', 'Levy Tran', 'Anna Colwell', 'Viktor Hernandez', 'Steve Coulter', 'Robert Pralgo', 'Antwan Mills', 'J.J. Phillips', 'Jorge Ferragut', 'Sara Sohn', 'Benjamin Blankenship', 'D.J. Hapa', 'T-Pain', 'Brian Mahoney', 'Brittney Alger', 'Romeo Santos', 'Jocelin Donahue', 'Stephanie Langston', 'Jorge-Luis Pallo', 'Tego Calderón', 'Nathalie Kelley', 'Shad Moss', 'Don Omar', 'Klement Tinaj', 'Caleb Walker', 'Cody Walker']

# %%
#Director
director=[]
for i in eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0]):
  if i['job']=='Director':
    director.append(i['name'])

print(director)
# Out:
# ['James Wan']

# %%
#Producer
Producer=[]
for i in eval(df[df['profit']==df['profit'].max()][['crew']].values[0][0]):
  if i['job']=='Producer':
    Producer.append(i['name'])

print(Producer)
# Out:
# ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']

# %% [markdown]
# 2.This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
df['ROI']=100*df['profit']/df['budget']
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.groupby(['original_language'])['ROI'].mean()
# Out:
# original_language
# ar            inf
# bn            inf
# cn            inf
# cs            inf
# da            inf
# de            inf
# el    5198.013245
# en            inf
# es            inf
# fa            inf
# fi     -30.319235
# fr            inf
# he     456.292450
# hi            inf
# hu            inf
# id     -41.617578
# it            inf
# ja            inf
# ko            inf
# ml     370.833333
# mr     193.333333
# nb      18.847943
# nl            inf
# no            inf
# pl     395.816987
# pt            inf
# ro            inf
# ru            inf
# sr     -99.960400
# sv            inf
# ta            inf
# te     440.076812
# tr            inf
# ur     350.673773
# vi     -50.846154
# zh            inf
# Name: ROI, dtype: float64

# %%
df.describe()
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#              profit          ROI
# count  3.000000e+03  3000.000000
# mean   4.419452e+07          inf
# std    1.123274e+08          NaN
# ...

# %%
df['revenue'].median()
# Out:
# 16807068.0

# %%
df['budget'].median()
# Out:
# 8000000.0

# %%
df.loc[df['revenue']<1000,'revenue']=df['revenue'].median()

# %%
df.loc[df['budget']<1000,'budget']=df['budget'].median()

# %%
df.describe()
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.474467e+07     8.463274   107.856571  6.704518e+07
# std     866.169729  3.583254e+07    12.104000    22.086434  1.373964e+08
# min       1.000000  2.500000e+03     0.000001     0.000000  1.404000e+03
# 25%     750.750000  8.000000e+06     4.018053    94.000000  2.947600e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680873e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#              profit          ROI
# count  3.000000e+03  3000.000000
# mean   4.419452e+07          inf
# std    1.123274e+08          NaN
# ...

# %%
df['profit'] = df['revenue']-df['budget']

# %%
df.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN   8000000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN   8000000
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...   8000000
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df['ROI']=100*df['profit']/df['budget']
df.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN   8000000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN   8000000
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...   8000000
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.groupby(['original_language'])['ROI'].mean().sort_values(ascending=False).head(10)
# Out:
# original_language
# ko    11309.685605
# el     5198.013245
# sr     3261.413600
# en      952.119148
# tr      878.917604
# de      550.245452
# he      456.292450
# te      440.076812
# pl      395.816987
# ml      370.833333
# Name: ROI, dtype: float64

# %% [markdown]
# 3.Find out the unique genres of movies in this dataset?

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit', 'ROI'],
#       dtype='object')

# %%
df['genres'].isnull().sum()
# Out:
# np.int64(7)

# %%
not_null_genres=df[~df['genres'].isna()]
not_null_genres['genres'].isnull().sum()
# Out:
# np.int64(0)

# %%
#In this method this is dome by removing all the null values
genres_list=[]
for i in not_null_genres['genres'][:]:
  for j in eval(i):
    genres_list.append(j['name'])


print(set(genres_list))
# Out:
# {'Crime', 'Comedy', 'Documentary', 'Action', 'Western', 'Science Fiction', 'Mystery', 'Fantasy', 'Thriller', 'Romance', 'Horror', 'Foreign', 'TV Movie', 'War', 'Family', 'Drama', 'Adventure', 'Animation', 'Music', 'History'}

# %%
genres_list1=[]
try:
  for i in df['genres'][:]:
    for j in eval(i):
      genres_list1.append(j['name'])

except:
  pass

print(set(genres_list1))
# Out:
# {'Crime', 'Comedy', 'Documentary', 'Action', 'Western', 'Science Fiction', 'Mystery', 'Fantasy', 'Thriller', 'Romance', 'Horror', 'Foreign', 'War', 'Family', 'Drama', 'Adventure', 'Animation', 'Music', 'History'}

# %% [markdown]
# 4.Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor?

# %%
movie_actor=[]

try:
  for i in df['cast'][:]:
    for j in eval(i):
      movie_actor.append(j['name'])

except:
  pass

print(set(movie_actor))
# Out:
# {'Michael Laauli Hayner', 'Jimmy Lin', 'Fiona Glascott', 'Miyavi', 'Alex Wolff', 'David Sterne', 'Liza Weil', 'Eriq La Salle', 'Ed Anders', 'Courtney Tailor', 'Jonathan Wilson', 'Nicholas Bell', 'Mari Jaramillo', 'Tommy Davidson', 'Caitlin Rose Anderson', 'Henry Kelemen', 'Lottie Hamilton', 'Veit Stübner', 'Antoine Laurent', 'Philip Barantini', 'Alina Babak', 'Rick Irwin', 'Taka Uematsu', 'Brad William Henke', 'Cress Williams', 'Paul Bettany', 'Phil Leeds', 'Fred Ward', 'Adam Storke', 'Vsevolod Tsurilo', 'Brenda Fricker', 'Danny Bonaduce', 'Maxwell Perry Cotton', 'Stephen Shellen', 'Divya Satia', 'Michele Brilliant', 'Kenneth Tobey', 'Andrew Blanchard', 'Robert Townsend', 'André Hennicke', 'Jeanne Bates', 'Jane Seymour', 'Don McManus', 'Drew Sawyer', 'Diane-Louise Jordan', 'Luis Callejo', 'Joshua Wolf Coleman', 'Diane Hartford', 'Big John', 'Igal Naor', 'Daniel Prévost', 'Roy C. Peterson', 'Henry Wilcoxon', 'David McConnell', 'Darcy Higginbotham', 'Minae Noji', 'Marta Kristen', 'C
# ...

# %%
actor_df=pd.DataFrame(movie_actor,columns=['cast'])

# %%
# Actor with the Most number of the film
actor_df.value_counts().sort_values(ascending=False)
# Out:
# cast
# Keith David        8
# Kathy Bates        7
# J.K. Simmons       7
# Chris Cooper       7
# Brendan Gleeson    7
#                   ..
# Val Maloku         1
# Val McDow          1
# Valarie Trapp      1
# Valdeci Junior     1
# Victor Haïm       1
# Name: count, Length: 8701, dtype: int64
