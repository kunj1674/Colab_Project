# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
a = pd.Series([1,2,3,4,5])
type(a)
# Out:
# pandas.core.series.Series

# %%
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a = pd.Series([1,2,3,4,5], index =['a','b','c','d','e'])
print(a)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(a['a'])
# Out:
# 1

# %%
print(a['c'])
# Out:
# 3

# %%
print(a['e'])
# Out:
# 5

# %%
a = np.random.randint(10,20,(2,2))

# %%
df=pd.DataFrame(a)

# %%
print(df)
# Out:
#     0   1
# 0  19  11
# 1  19  13

# %%
df=pd.DataFrame(a,columns=['apple','Oranges'],index=['1','2'])
print(df)
# Out:
#    apple  Oranges
# 1     19       11
# 2     19       13

# %%
a=[['Rohan',20],['Mohan',21],['Sohan',22]]
df = pd.DataFrame(a)
df
# Out:
#        0   1
# 0  Rohan  20
# 1  Mohan  21
# 2  Sohan  22

# %%
df= pd.DataFrame(a,columns=['Name','Age'],index=['1','2','3'])
print(df)
df
# Out:
#     Name  Age
# 1  Rohan   20
# 2  Mohan   21
# 3  Sohan   22
#     Name  Age
# 1  Rohan   20
# 2  Mohan   21
# 3  Sohan   22

# %% [markdown]
# Creating dataframe with the help of the array of 51 rows and 5 columns

# %%
a = np.random.randint(11,21,(51,5))
df = pd.DataFrame(a,columns=['a','b','c','d','e'])
df
# Out:
#      a   b   c   d   e
# 0   13  18  15  11  17
# 1   12  17  20  15  18
# 2   19  12  12  12  14
# 3   16  11  17  17  18
# 4   13  15  11  16  15
# 5   15  12  11  11  19
# 6   17  19  11  15  18
# 7   14  18  11  19  11
# 8   20  15  15  17  15
# 9   12  11  16  16  15
# 10  20  14  17  12  19
# 11  20  18  16  18  18
# 12  14  20  17  11  20
# 13  12  16  12  16  13
# 14  11  14  20  13  12
# 15  15  20  13  13  12
# 16  19  20  12  15  16
# 17  13  15  12  18  11
# 18  12  20  11  18  19
# 19  12  12  14  15  18
# 20  14  17  19  11  19
# 21  11  20  18  13  12
# 22  12  17  18  12  13
# 23  17  16  14  11  11
# 24  15  14  18  17  20
# 25  18  12  13  16  20
# 26  14  17  16  14  19
# 27  13  20  15  13  13
# 28  13  14  15  20  15
# 29  18  13  11  14  14
# 30  12  17  11  17  12
# 31  14  13  12  12  14
# 32  13  19  14  16  19
# 33  19  20  18  18  11
# 34  14  11  16  16  17
# 35  12  16  18  11  15
# 36  19  13  20  14  13
# 37  20  15  20  11  17
# 38  12  19  18  13  20
# ...

# %%
a = {'name':['Virat','Visheshata','Kunj'],'age':['21','21','22']}
df=pd.DataFrame(a)
df
# Out:
#          name age
# 0       Virat  21
# 1  Visheshata  21
# 2        Kunj  22

# %%
df.tail
# Out:
# <bound method NDFrame.tail of          name age
# 0       Virat  21
# 1  Visheshata  21
# 2        Kunj  22>

# %%
df.tail(7)
# Out:
#      a   b   c   d   e
# 44  15  19  20  19  19
# 45  18  16  18  14  14
# 46  12  12  11  16  18
# 47  13  18  11  11  18
# 48  12  17  15  13  14
# 49  17  14  16  19  19
# 50  16  11  11  18  15

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       51 non-null     int64
#  1   b       51 non-null     int64
#  2   c       51 non-null     int64
#  3   d       51 non-null     int64
#  4   e       51 non-null     int64
# dtypes: int64(5)
# memory usage: 2.1 KB

# %% [markdown]
# Original DataFrame connection and other Functionalities

# %%
path = '/content/drive/MyDrive/Colab Notebooks/imdb_data.csv'

# %%
df = pd.read_csv(path)
df.head(7)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.iloc[0:6,0:7]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
#
#                             homepage    imdb_id original_language
# ...

# %%
df['title']
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
df[['title','genres','original_language']]
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                  genres original_language
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# ...

# %%
df.loc[ :7,['title','genres','original_language']]
# Out:
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
#
#                                               genres original_language
# 0                     [{'id': 35, 'name': 'Comedy'}]                en
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                      [{'id': 18, 'name': 'Drama'}]                en
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...                en
# ...

# %%
df['popularity']
# Out:
# 0        6.575393
# 1        8.248895
# 2       64.299990
# 3        3.174936
# 4        1.148070
#           ...
# 2995     9.853270
# 2996     3.727996
# 2997    14.482345
# 2998    15.725542
# 2999    10.512109
# Name: popularity, Length: 3000, dtype: float64

# %%
df[df['popularity']==df['popularity'].max()][['title','popularity']]
# Out:
#             title  popularity
# 518  Wonder Woman  294.337037

# %%
df[df['original_language']=='hi']
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# ...

# %%
df_hindi=df[df['original_language']=='hi']
df_hindi[df_hindi['popularity']==df_hindi['popularity'].max()][['title','popularity','runtime']]
# Out:
#              title  popularity  runtime
# 2353  Jodhaa Akbar   12.237488    213.0

# %%
df['half_runtime']=df['runtime']/2

# %%
df.head(7)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime'],
#       dtype='object')

# %%
df['Profit']=df['revenue']-df['budget']

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df[df['Profit']==df['Profit'].max()][['title','Profit','runtime']]
# Out:
#           title      Profit  runtime
# 1761  Furious 7  1316249360    137.0

# %% [markdown]
# I want to find the most Profitable film of the Hindi Langauage

# %%
film_hindi = df[df['original_language']=='hi']
film_hindi[film_hindi['Profit']==film_hindi['Profit'].max()][['title','Profit','runtime']]
# Out:
#       title     Profit  runtime
# 585  Dangal  299600000    161.0

# %%
df_korean = df[df['original_language']=='ko']
df_korean=df_korean[df_korean['Profit']==df_korean['Profit'].max()][['title','Profit','runtime']]

# %%
df_korean = df[df['original_language']=='ko']
df_korean=df_korean[df_korean['Profit']==df_korean['Profit'].max()][['title','Profit']]
print(df_korean)
# Out:
#            title    Profit
# 147  Snowpiercer  47558912

# %%
film_hindi = df[df['original_language']=='hi']
film_hindi[film_hindi['Profit']==film_hindi['Profit'].max()][['title','Profit','runtime']]
# Out:
#       title     Profit  runtime
# 585  Dangal  299600000    161.0

# %% [markdown]
# We can also drop(remove) the column which we wanted

# %%
df.drop(columns=['runtime'],inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'spoken_languages', 'status',
#        'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# More Basics Operations

# %%
df['Profit'].mean()
# Out:
# np.float64(44194517.77866667)

# %%
df['Profit'].median()
# Out:
# 6121122.5

# %%
df['Profit'].mode()
# Out:
# 0    0
# Name: Profit, dtype: int64

# %%
df['Profit'].sum()
# Out:
# np.int64(132583553336)

# %% [markdown]
# use of apply() function

# %%
df['title']
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
def convert_upper(column):
  return column.upper()

# %%
df['title_upper']=df['title'].apply(convert_upper)

# %%
df.head(7)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...

# %% [markdown]
# Lambda Function

# %%
def add_ab(a,b):
  return a+b

# %%
add_ab(10,20)
# Out:
# 30

# %%
x= lambda a,b: a+b

# %%
x(10,30)
# Out:
# 40

# %%
def new_p(revenue,budget):
  return revenue - budget

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'spoken_languages', 'status',
#        'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'Profit', 'title_upper'],
#       dtype='object')

# %%
df['new_profit']=df.apply(lambda x: new_p(x['revenue'],x['budget']),axis=1)

# %%
df.head(7)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...

# %%
df.sort_values('revenue',ascending=False)[['title','revenue','Profit']]
# Out:
#                                title     revenue      Profit
# 1126                    The Avengers  1519557910  1299557910
# 1761                       Furious 7  1506249360  1316249360
# 2770         Avengers: Age of Ultron  1405403694  1125403694
# 684             Beauty and the Beast  1262886337  1102886337
# 2322  Transformers: Dark of the Moon  1123746996   928746996
# ...                              ...         ...         ...
# 695                        Tere Naam           2           1
# 1917                 The Merry Widow           1        -591
# 347          The Wind in the Willows           1         -11
# 1754                    Mute Witness           1          -1
# 1874                         Missing           1           1
#
# [3000 rows x 3 columns]

# %%
df.sort_values('Profit',ascending=False)[['title','Profit','revenue']]
# Out:
#                                             title      Profit     revenue
# 1761                                    Furious 7  1316249360  1506249360
# 1126                                 The Avengers  1299557910  1519557910
# 2770                      Avengers: Age of Ultron  1125403694  1405403694
# 684                          Beauty and the Beast  1102886337  1262886337
# 2322               Transformers: Dark of the Moon   928746996  1123746996
# ...                                           ...         ...         ...
# 776                                     Australia   -80445998    49554002
# 307                                 Live by Night   -85321445    22678555
# 251                              Cutthroat Island   -87982678    10017322
# 2278                 The Adventures of Pluto Nash   -92896027     7103973
# 2623  Valerian and the City of a Thousand Planets  -107447384    90024292
#
# [3000 rows x 3 columns]

# %% [markdown]
# use of date time operations and functions in dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['release_date']=pd.to_datetime(df['release_date'])
# Out:
# /tmp/ipykernel_1277/642638228.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date']=pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
print(df['release_date'][0])
# Out:
# 2015-02-20 00:00:00

# %%
print(df['release_date'][0].year)
# Out:
# 2015

# %%
print(df['release_date'][90])
# Out:
# 2003-10-10 00:00:00

# %%
print(df['release_date'][90].year)
# Out:
# 2003

# %%
print(df['release_date'][0].day_name())
# Out:
# Friday

# %%
print(df['release_date'][0].weekday())
# Out:
# 4

# %%
df['original_language']
# Out:
# 0       en
# 1       en
# 2       en
# 3       hi
# 4       ko
#         ..
# 2995    en
# 2996    sv
# 2997    en
# 2998    en
# 2999    en
# Name: original_language, Length: 3000, dtype: object

# %%
df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# ko      20
# cn      20
# zh      19
# de      18
# ta      16
# sv       8
# pt       6
# nl       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# te       2
# pl       2
# fi       2
# ml       2
# sr       1
# cs       1
# mr       1
# ar       1
# he       1
# ur       1
# el       1
# vi       1
# nb       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df['original_language'].nunique()
# Out:
# 36

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# half_runtime                2
# Profit                      0
# dtype: int64

# %%
print(df['belongs_to_collection'].isnull().sum())
# Out:
# 2396

# %%
df['belongs_to_collection'].isnull().sum()
# Out:
# np.int64(2396)

# %%
df['belongs_to_collection'].fillna('Not Present',inplace=True)
# Out:
# /tmp/ipykernel_1277/2051677013.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['belongs_to_collection'].fillna('Not Present',inplace=True)

# %%
df['belongs_to_collection'].isnull().sum()
# Out:
# np.int64(0)
